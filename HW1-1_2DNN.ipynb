# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
batch_size = 64
n_batch = mnist.train.num_examples // batch_size

learning_rate = 0.01
# Out:
# WARNING:tensorflow:From <ipython-input-3-87be4e0cd892>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/lingyis/.conda/envs/8810/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/lingyis/.conda/envs/8810/lib/python3.6/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
tf.reset_default_graph()
x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None, 10])

hiden_layer1_1 = tf.layers.dense(x, 5, activation= tf.nn.leaky_relu)
hiden_layer2_1 = tf.layers.dense(hiden_layer1_1, 10, activation=tf.nn.leaky_relu)
hiden_layer3_1 = tf.layers.dense(hiden_layer2_1, 10, activation=tf.nn.leaky_relu)
hiden_layer4_1 = tf.layers.dense(hiden_layer3_1, 10, activation=tf.nn.leaky_relu)
hiden_layer5_1 = tf.layers.dense(hiden_layer4_1, 10, activation=tf.nn.leaky_relu)
hiden_layer6_1 = tf.layers.dense(hiden_layer5_1, 10, activation=tf.nn.leaky_relu)
hiden_layer7_1 = tf.layers.dense(hiden_layer6_1, 5, activation=tf.nn.leaky_relu)
prediction_1 = tf.layers.dense(hiden_layer7_1,10)

cross_entropy1 = tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction_1)
loss = tf.reduce_mean(cross_entropy1)


train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)


init = tf.global_variables_initializer()


correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction_1,1))

accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))


losslist1 = []
acclist1 = []
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(50):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_xs, y:batch_ys})
        acc,los = sess.run([accuracy,loss], feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Epoch " + str(epoch) + " Testing Accuracy: " + str(acc))
        losslist1.append(los)
        acclist1.append(acc)
# Out:
# Epoch 0 Testing Accuracy: 0.8364
# Epoch 1 Testing Accuracy: 0.8631
# Epoch 2 Testing Accuracy: 0.8789
# Epoch 3 Testing Accuracy: 0.8878
# Epoch 4 Testing Accuracy: 0.895
# Epoch 5 Testing Accuracy: 0.8952
# Epoch 6 Testing Accuracy: 0.9025
# Epoch 7 Testing Accuracy: 0.8992
# Epoch 8 Testing Accuracy: 0.9041
# Epoch 9 Testing Accuracy: 0.9048
# Epoch 10 Testing Accuracy: 0.9035
# Epoch 11 Testing Accuracy: 0.9099
# Epoch 12 Testing Accuracy: 0.8985
# Epoch 13 Testing Accuracy: 0.9075
# Epoch 14 Testing Accuracy: 0.8993
# Epoch 15 Testing Accuracy: 0.9094
# Epoch 16 Testing Accuracy: 0.9093
# Epoch 17 Testing Accuracy: 0.9002
# Epoch 18 Testing Accuracy: 0.9087
# Epoch 19 Testing Accuracy: 0.9036
# Epoch 20 Testing Accuracy: 0.9091
# Epoch 21 Testing Accuracy: 0.9116
# Epoch 22 Testing Accuracy: 0.9095
# Epoch 23 Testing Accuracy: 0.9088
# Epoch 24 Testing Accuracy: 0.9111
# Epoch 25 Testing Accuracy: 0.9114
# Epoch 26 Testing Accuracy: 0.907
# Epoch 27 Testing Accuracy: 0.9128
# ...

# %%
tf.reset_default_graph()

x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None, 10])

hiden_layer1_2 = tf.layers.dense(x, 10, activation= tf.nn.leaky_relu)
hiden_layer2_2 = tf.layers.dense(hiden_layer1_2, 18, activation=tf.nn.leaky_relu)
hiden_layer3_2 = tf.layers.dense(hiden_layer2_2, 15, activation=tf.nn.leaky_relu)
hiden_layer4_2 = tf.layers.dense(hiden_layer3_2, 4, activation=tf.nn.leaky_relu)
prediction_2 = tf.layers.dense(hiden_layer4_2,10, name = 'm2_o')


init = tf.global_variables_initializer()

cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction_2)
loss = tf.reduce_mean(cross_entropy)


train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)


init = tf.global_variables_initializer()


correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction_2,1))

accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

losslist2 = []
acclist2 = []
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(50):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_xs, y:batch_ys})
        acc,los = sess.run([accuracy,loss], feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Epoch " + str(epoch) + " Testing Accuracy: " + str(acc))
        losslist2.append(los)
        acclist2.append(acc)
# Out:
# Epoch 0 Testing Accuracy: 0.8995
# Epoch 1 Testing Accuracy: 0.9215
# Epoch 2 Testing Accuracy: 0.929
# Epoch 3 Testing Accuracy: 0.9297
# Epoch 4 Testing Accuracy: 0.9356
# Epoch 5 Testing Accuracy: 0.9371
# Epoch 6 Testing Accuracy: 0.9311
# Epoch 7 Testing Accuracy: 0.939
# Epoch 8 Testing Accuracy: 0.9394
# Epoch 9 Testing Accuracy: 0.9385
# Epoch 10 Testing Accuracy: 0.9433
# Epoch 11 Testing Accuracy: 0.9364
# Epoch 12 Testing Accuracy: 0.9418
# Epoch 13 Testing Accuracy: 0.9453
# Epoch 14 Testing Accuracy: 0.9365
# Epoch 15 Testing Accuracy: 0.9439
# Epoch 16 Testing Accuracy: 0.9442
# Epoch 17 Testing Accuracy: 0.9434
# Epoch 18 Testing Accuracy: 0.9435
# Epoch 19 Testing Accuracy: 0.94
# Epoch 20 Testing Accuracy: 0.934
# Epoch 21 Testing Accuracy: 0.9459
# Epoch 22 Testing Accuracy: 0.9372
# Epoch 23 Testing Accuracy: 0.9412
# Epoch 24 Testing Accuracy: 0.9436
# Epoch 25 Testing Accuracy: 0.9442
# Epoch 26 Testing Accuracy: 0.9461
# Epoch 27 Testing Accuracy: 0.9443
# ...

# %%
tf.reset_default_graph()
x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None, 10])

hiden_layer1_3 = tf.layers.dense(x, 190, activation= tf.nn.leaky_relu)
prediction_3 = tf.layers.dense(hiden_layer1_3,10)
Loss_3 =tf.losses.mean_squared_error(y, prediction_3)


init = tf.global_variables_initializer()

cross_entropy3 = tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction_3)
loss = tf.reduce_mean(cross_entropy3)


train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)


init = tf.global_variables_initializer()


correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction_3,1))

accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

losslist3 = []
acclist3 = []
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(50):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_xs, y:batch_ys})
        acc,los = sess.run([accuracy,loss], feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Epoch " + str(epoch) + " Testing Accuracy: " + str(acc))
        losslist3.append(los)
        acclist3.append(acc)
# Out:
# Epoch 0 Testing Accuracy: 0.944
# Epoch 1 Testing Accuracy: 0.9487
# Epoch 2 Testing Accuracy: 0.9442
# Epoch 3 Testing Accuracy: 0.9481
# Epoch 4 Testing Accuracy: 0.9556
# Epoch 5 Testing Accuracy: 0.9519
# Epoch 6 Testing Accuracy: 0.9598
# Epoch 7 Testing Accuracy: 0.962
# Epoch 8 Testing Accuracy: 0.961
# Epoch 9 Testing Accuracy: 0.9573
# Epoch 10 Testing Accuracy: 0.9654
# Epoch 11 Testing Accuracy: 0.9671
# Epoch 12 Testing Accuracy: 0.9595
# Epoch 13 Testing Accuracy: 0.965
# Epoch 14 Testing Accuracy: 0.9569
# Epoch 15 Testing Accuracy: 0.9672
# Epoch 16 Testing Accuracy: 0.9683
# Epoch 17 Testing Accuracy: 0.9582
# Epoch 18 Testing Accuracy: 0.97
# Epoch 19 Testing Accuracy: 0.9637
# Epoch 20 Testing Accuracy: 0.9688
# Epoch 21 Testing Accuracy: 0.967
# Epoch 22 Testing Accuracy: 0.9665
# Epoch 23 Testing Accuracy: 0.9632
# Epoch 24 Testing Accuracy: 0.9717
# Epoch 25 Testing Accuracy: 0.9655
# Epoch 26 Testing Accuracy: 0.9682
# Epoch 27 Testing Accuracy: 0.9697
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(acclist1)
plt.plot(acclist2)
plt.plot(acclist3)
plt.title('Model accuracy')
plt.ylabel('acc')
plt.xlabel('Epoch')
plt.legend(('Model1','Model2','Model3'))
plt.show()

plt.plot(losslist1)
plt.plot(losslist2)
plt.plot(losslist3)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(('Model1','Model2','Model3'))
plt.show()
